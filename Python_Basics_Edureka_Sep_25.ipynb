# %% [markdown]
# <a href="https://colab.research.google.com/github/vjatgit/Complete-Python-3-Bootcamp/blob/master/Python_Basics_Edureka_Sep_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Basics**

# %%
print("Hello to python world")
# Out:
# Hello to python world

# %% [markdown]
# **Variables**
# A python variable is reserved memory location to store any values

# %%
age=45
print(age)

age=55
print(age)

print(id(age))

print(hex(id(age)))

print(type(age))
# Out:
# 45
# 55
# 11643816
# 0xb1aba8
# <class 'int'>

# %%
#Rules for Variable names
var123=45
#123var=100 #varaible names must start from an alphabate
#!@#$%^&*()

total_amount=15200
#keywords: if,for,class

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Python is case sensetive language
amount=1000
Amount=2000
print(Amount)
# Out:
# 2000

# %% [markdown]
# **Python Data types: Numerical Datatypes, strings, Sequences(collection datatypes)**

# %%
age=45
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# Numerical Data types: int,float,complex
